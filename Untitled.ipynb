# %%
import numpy as np
from matplotlib.patches import Ellipse
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
A, B = 1,  0.5

x, y = np.random.rand(200, 2).T
x = MinMaxScaler((-A, A)).fit_transform(x.reshape(-1, 1)).ravel()
y = MinMaxScaler((-B, B)).fit_transform(y.reshape(-1, 1)).ravel()

pts_out = (x ** 2) / (A ** 2) + (y ** 2) / (B ** 2) < 1
x_in = x[pts_out]
y_in = y[pts_out]

C = np.cov(np.c_[x_in, y_in].T)
w, v= np.linalg.eig(C)


fig, ax = plt.subplots(figsize=(12, 8))

ax.scatter(x, y, alpha=0.5)
ax.scatter(x_in, y_in, alpha=0.5)

el = Ellipse((0, 0), 2 * A, 2 * B, fill=False)
ax.add_patch(el)
ax.axis([-1.5, 1.5, -1, 1])

(e1dx, e1dy), (e2dx, e2dy) = (3 * w * v).T
ax.arrow(0, 0, e1dx, e1dy, color='g', width=0.01)
ax.arrow(0, 0, e2dx, e2dy, color='r', width=0.01)

# %%
X, Y = x_in, y_in

# %%
Z = np.c_[X, Y]

# %%
C = np.cov(Z.T)

# %%
w, v = np.linalg.eig(C)

# %%
w
# Out:
# array([0.24218041, 0.06706473])

# %%
v
# Out:
# array([[ 0.99995682,  0.00929246],
#        [-0.00929246,  0.99995682]])

# %%
e1dx, e1dy
# Out:
# (0.9998919922138102, -0.01469707136465426)

# %%
v
# Out:
# array([[ 0.99989199,  0.01469707],
#        [-0.01469707,  0.99989199]])

# %%
e2dx, e2dy
# Out:
# (0.01469707136465426, 0.9998919922138102)

# %%
w
# Out:
# array([0.24626471, 0.06344198])

# %%
v
# Out:
# array([[ 0.99989199,  0.01469707],
#        [-0.01469707,  0.99989199]])

# %%
w * v
# Out:
# array([[ 0.24623812,  0.00093241],
#        [-0.00361937,  0.06343513]])
